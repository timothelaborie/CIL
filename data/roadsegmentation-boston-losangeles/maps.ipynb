# %%
import requests
import cv2
import numpy as np
import os
import random

# Make sure your directories exist
if not os.path.exists('images'):
    os.makedirs('images')
    
if not os.path.exists('groundtruth'):
    os.makedirs('groundtruth')

def get_random_images_and_masks(latitude, longitude, iteration, name):
    zoom = 18
    # Increase the size to crop out watermark
    size = "500x500"
    maptype = "satellite"
    base_url = "https://maps.googleapis.com/maps/api/staticmap?"
    api_key = np.load("api_key.npy")[0]
    style = "&style=feature:all|element:all|visibility:off&style=feature:road|element:geometry|visibility:on|color:0xff0000"

    
    # Fetch styled map image
    url = base_url + "center={},{}&zoom={}&size={}&key={}".format(
        latitude, longitude, zoom, size, api_key
    ) + style

    response = requests.get(url)
    
    if response.status_code == 200:
        styled_map_img_name = "groundtruth_orig_{}.png".format(iteration)
        with open(styled_map_img_name, 'wb') as f:
            f.write(response.content)
    else:
        print("Error in getting the image", response.status_code)

    # Convert styled map to binary mask
    image = cv2.imread(styled_map_img_name)
    
    # Crop the image to original size and remove watermark
    cropped_image = image[50:450, 50:450]
    
    gray_image = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
    _, mask = cv2.threshold(gray_image, 1, 255, cv2.THRESH_BINARY)

    mask_img_name = 'groundtruth/' + name + "_{}.png".format(iteration)
    cv2.imwrite(mask_img_name, mask)
    os.remove(styled_map_img_name)  # remove the unprocessed road mask

    # Fetch satellite image
    url = base_url + "center={},{}&zoom={}&size={}&maptype={}&key={}".format(
        latitude, longitude, zoom, size, maptype, api_key
    )

    response = requests.get(url)
    
    if response.status_code == 200:
        satellite_img_name = "images/" + name + "_{}.jpg".format(iteration)
        with open(satellite_img_name, 'wb') as f:
            f.write(response.content)
        
        # Read the image back in
        image = cv2.imread(satellite_img_name)
        
        # Crop the image to remove watermark
        cropped_image = image[50:450, 50:450]
        
        # Overwrite the original image with the cropped one
        cv2.imwrite(satellite_img_name, cropped_image)
    else:
        print("Error in getting the image", response.status_code)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Coordinates for boston
bottomleft = "https://www.google.ch/maps/@42.2658472,-71.2045493,1662m/data=!3m1!1e3?hl=en&entry=ttu"
topright = "https://www.google.ch/maps/@42.4729855,-70.9741368,1656m/data=!3m1!1e3?hl=en&entry=ttu"

latitude_min = float(bottomleft.split("@")[1].split(",")[0])
latitude_max = float(topright.split("@")[1].split(",")[0])
longitude_min = float(bottomleft.split("@")[1].split(",")[1])
longitude_max = float(topright.split("@")[1].split(",")[1])


i = 0
# Run the function to obtain all the images and masks within the specified coordinates
for latitude in np.arange(latitude_min, latitude_max, 0.002):
    for longitude in np.arange(longitude_min, longitude_max, 0.002):
        if i > 9120:
            get_random_images_and_masks(latitude, longitude, i, "boston")
        i += 1
        if i % 10 == 0:
            print(i, "images downloaded")
    #     if i > 2:
    #         break
    # if i > 2:
    #     break

# %%
# Coordinates for los angeles
bottomleft = "https://www.google.ch/maps/@33.8096648,-118.3861435,1866m/data=!3m1!1e3?hl=en&entry=ttu"
topright = "https://www.google.ch/maps/@34.0464906,-118.0906229,465m/data=!3m1!1e3?hl=en&entry=ttu"

latitude_min = float(bottomleft.split("@")[1].split(",")[0])
latitude_max = float(topright.split("@")[1].split(",")[0])
longitude_min = float(bottomleft.split("@")[1].split(",")[1])
longitude_max = float(topright.split("@")[1].split(",")[1])

i = 0
# Run the function to obtain all the images and masks within the specified coordinates
for latitude in np.arange(latitude_min, latitude_max, 0.0027):
    for longitude in np.arange(longitude_min, longitude_max, 0.0027):
        if i > 1695:
            get_random_images_and_masks(latitude, longitude, i, "losangeles")
        i += 1
        if i % 10 == 0:
            print(i, "images downloaded")
    #     if i > 10:
    #         break
    # if i > 2:
    #     break
# Out:
# 10 images downloaded
# 20 images downloaded
# 30 images downloaded
# 40 images downloaded
# 50 images downloaded
# 60 images downloaded
# 70 images downloaded
# 80 images downloaded
# 90 images downloaded
# 100 images downloaded
# 110 images downloaded
# 120 images downloaded
# 130 images downloaded
# 140 images downloaded
# 150 images downloaded
# 160 images downloaded
# 170 images downloaded
# 180 images downloaded
# 190 images downloaded
# 200 images downloaded
# 210 images downloaded
# 220 images downloaded
# 230 images downloaded
# 240 images downloaded
# 250 images downloaded
# 260 images downloaded
# 270 images downloaded
# 280 images downloaded
# 290 images downloaded
# 300 images downloaded
# 310 images downloaded
# 320 images downloaded
# 330 images downloaded
# 340 images downloaded
# 350 images downloaded
# 360 images downloaded
# 370 images downloaded
# 380 images downloaded
# 390 images downloaded
# 400 images downloaded
# 410 images downloaded
# 420 images downloaded
# 430 images downloaded
# 440 images downloaded
# 450 images downloaded
# 460 images downloaded
# 470 images downloaded
# 480 images downloaded
# 490 images downloaded
# 500 images downloaded
# 510 images downloaded
# 520 images downloaded
# 530 images downloaded
# 540 images downloaded
# 550 images downloaded
# 560 images downloaded
# 570 images downloaded
# 580 images downloaded
# 590 images downloaded
# 600 images downloaded
# 610 images downloaded
# 620 images downloaded
# 630 images downloaded
# 640 images downloaded
# 650 images downloaded
# 660 images downloaded
# 670 images downloaded
# 680 images downloaded
# 690 images downloaded
# 700 images downloaded
# 710 images downloaded
# 720 images downloaded
# 730 images downloaded
# 740 images downloaded
# 750 images downloaded
# 760 images downloaded
# 770 images downloaded
# 780 images downloaded
# 790 images downloaded
# 800 images downloaded
# 810 images downloaded
# 820 images downloaded
# 830 images downloaded
# 840 images downloaded
# 850 images downloaded
# 860 images downloaded
# 870 images downloaded
# 880 images downloaded
# 890 images downloaded
# 900 images downloaded
# 910 images downloaded
# 920 images downloaded
# 930 images downloaded
# 940 images downloaded
# 950 images downloaded
# 960 images downloaded
# 970 images downloaded
# 980 images downloaded
# 990 images downloaded
# 1000 images downloaded
# 1010 images downloaded
# 1020 images downloaded
# 1030 images downloaded
# 1040 images downloaded
# 1050 images downloaded
# 1060 images downloaded
# 1070 images downloaded
# 1080 images downloaded
# 1090 images downloaded
# 1100 images downloaded
# 1110 images downloaded
# 1120 images downloaded
# 1130 images downloaded
# 1140 images downloaded
# 1150 images downloaded
# 1160 images downloaded
# 1170 images downloaded
# 1180 images downloaded
# 1190 images downloaded
# 1200 images downloaded
# 1210 images downloaded
# 1220 images downloaded
# 1230 images downloaded
# 1240 images downloaded
# 1250 images downloaded
# 1260 images downloaded
# 1270 images downloaded
# 1280 images downloaded
# 1290 images downloaded
# 1300 images downloaded
# 1310 images downloaded
# 1320 images downloaded
# 1330 images downloaded
# 1340 images downloaded
# 1350 images downloaded
# 1360 images downloaded
# 1370 images downloaded
# 1380 images downloaded
# 1390 images downloaded
# 1400 images downloaded
# 1410 images downloaded
# 1420 images downloaded
# 1430 images downloaded
# 1440 images downloaded
# 1450 images downloaded
# 1460 images downloaded
# 1470 images downloaded
# 1480 images downloaded
# 1490 images downloaded
# 1500 images downloaded
# 1510 images downloaded
# 1520 images downloaded
# 1530 images downloaded
# 1540 images downloaded
# 1550 images downloaded
# 1560 images downloaded
# 1570 images downloaded
# 1580 images downloaded
# 1590 images downloaded
# 1600 images downloaded
# 1610 images downloaded
# 1620 images downloaded
# 1630 images downloaded
# 1640 images downloaded
# 1650 images downloaded
# 1660 images downloaded
# 1670 images downloaded
# 1680 images downloaded
# 1690 images downloaded
# 1700 images downloaded
# 1710 images downloaded
# 1720 images downloaded
# 1730 images downloaded
# 1740 images downloaded
# 1750 images downloaded
# 1760 images downloaded
# 1770 images downloaded
# 1780 images downloaded
# 1790 images downloaded
# 1800 images downloaded
# 1810 images downloaded
# 1820 images downloaded
# 1830 images downloaded
# 1840 images downloaded
# 1850 images downloaded
# 1860 images downloaded
# 1870 images downloaded
# 1880 images downloaded
# 1890 images downloaded
# 1900 images downloaded
# 1910 images downloaded
# 1920 images downloaded
# 1930 images downloaded
# 1940 images downloaded
# 1950 images downloaded
# 1960 images downloaded
# 1970 images downloaded
# 1980 images downloaded
# 1990 images downloaded
# 2000 images downloaded
# 2010 images downloaded
# 2020 images downloaded
# 2030 images downloaded
# 2040 images downloaded
# 2050 images downloaded
# 2060 images downloaded
# 2070 images downloaded
# 2080 images downloaded
# 2090 images downloaded
# 2100 images downloaded
# 2110 images downloaded
# 2120 images downloaded
# 2130 images downloaded
# 2140 images downloaded
# 2150 images downloaded
# 2160 images downloaded
# 2170 images downloaded
# 2180 images downloaded
# 2190 images downloaded
# 2200 images downloaded
# 2210 images downloaded
# 2220 images downloaded
# 2230 images downloaded
# 2240 images downloaded
# 2250 images downloaded
# 2260 images downloaded
# 2270 images downloaded
# 2280 images downloaded
# 2290 images downloaded
# 2300 images downloaded
# 2310 images downloaded
# 2320 images downloaded
# 2330 images downloaded
# 2340 images downloaded
# 2350 images downloaded
# 2360 images downloaded
# 2370 images downloaded
# 2380 images downloaded
# 2390 images downloaded
# 2400 images downloaded
# 2410 images downloaded
# 2420 images downloaded
# 2430 images downloaded
# 2440 images downloaded
# 2450 images downloaded
# 2460 images downloaded
# 2470 images downloaded
# 2480 images downloaded
# 2490 images downloaded
# 2500 images downloaded
# 2510 images downloaded
# 2520 images downloaded
# 2530 images downloaded
# 2540 images downloaded
# 2550 images downloaded
# 2560 images downloaded
# 2570 images downloaded
# 2580 images downloaded
# 2590 images downloaded
# 2600 images downloaded
# 2610 images downloaded
# 2620 images downloaded
# 2630 images downloaded
# 2640 images downloaded
# 2650 images downloaded
# 2660 images downloaded
# 2670 images downloaded
# 2680 images downloaded
# 2690 images downloaded
# 2700 images downloaded
# 2710 images downloaded
# 2720 images downloaded
# 2730 images downloaded
# 2740 images downloaded
# 2750 images downloaded
# 2760 images downloaded
# 2770 images downloaded
# 2780 images downloaded
# 2790 images downloaded
# 2800 images downloaded
# 2810 images downloaded
# 2820 images downloaded
# 2830 images downloaded
# 2840 images downloaded
# 2850 images downloaded
# 2860 images downloaded
# 2870 images downloaded
# 2880 images downloaded
# 2890 images downloaded
# 2900 images downloaded
# 2910 images downloaded
# 2920 images downloaded
# 2930 images downloaded
# 2940 images downloaded
# 2950 images downloaded
# 2960 images downloaded
# 2970 images downloaded
# 2980 images downloaded
# 2990 images downloaded
# 3000 images downloaded
# 3010 images downloaded
# 3020 images downloaded
# 3030 images downloaded
# 3040 images downloaded
# 3050 images downloaded
# 3060 images downloaded
# 3070 images downloaded
# 3080 images downloaded
# 3090 images downloaded
# 3100 images downloaded
# 3110 images downloaded
# 3120 images downloaded
# 3130 images downloaded
# 3140 images downloaded
# 3150 images downloaded
# 3160 images downloaded
# 3170 images downloaded
# 3180 images downloaded
# 3190 images downloaded
# 3200 images downloaded
# 3210 images downloaded
# 3220 images downloaded
# 3230 images downloaded
# 3240 images downloaded
# 3250 images downloaded
# 3260 images downloaded
# 3270 images downloaded
# 3280 images downloaded
# 3290 images downloaded
# 3300 images downloaded
# 3310 images downloaded
# 3320 images downloaded
# 3330 images downloaded
# 3340 images downloaded
# 3350 images downloaded
# 3360 images downloaded
# 3370 images downloaded
# 3380 images downloaded
# 3390 images downloaded
# 3400 images downloaded
# 3410 images downloaded
# 3420 images downloaded
# 3430 images downloaded
# 3440 images downloaded
# 3450 images downloaded
# 3460 images downloaded
# 3470 images downloaded
# 3480 images downloaded
# 3490 images downloaded
# 3500 images downloaded
# 3510 images downloaded
# 3520 images downloaded
# 3530 images downloaded
# 3540 images downloaded
# 3550 images downloaded
# 3560 images downloaded
# 3570 images downloaded
# 3580 images downloaded
# 3590 images downloaded
# 3600 images downloaded
# 3610 images downloaded
# 3620 images downloaded
# 3630 images downloaded
# 3640 images downloaded
# 3650 images downloaded
# 3660 images downloaded
# 3670 images downloaded
# 3680 images downloaded
# 3690 images downloaded
# 3700 images downloaded
# 3710 images downloaded
# 3720 images downloaded
# 3730 images downloaded
# 3740 images downloaded
# 3750 images downloaded
# 3760 images downloaded
# 3770 images downloaded
# 3780 images downloaded
# 3790 images downloaded
# 3800 images downloaded
# 3810 images downloaded
# 3820 images downloaded
# 3830 images downloaded
# 3840 images downloaded
# 3850 images downloaded
# 3860 images downloaded
# 3870 images downloaded
# 3880 images downloaded
# 3890 images downloaded
# 3900 images downloaded
# 3910 images downloaded
# 3920 images downloaded
# 3930 images downloaded
# 3940 images downloaded
# 3950 images downloaded
# 3960 images downloaded
# 3970 images downloaded
# 3980 images downloaded
# 3990 images downloaded
# 4000 images downloaded
# 4010 images downloaded
# 4020 images downloaded
# 4030 images downloaded
# 4040 images downloaded
# 4050 images downloaded
# 4060 images downloaded
# 4070 images downloaded
# 4080 images downloaded
# 4090 images downloaded
# 4100 images downloaded
# 4110 images downloaded
# 4120 images downloaded
# 4130 images downloaded
# 4140 images downloaded
# 4150 images downloaded
# 4160 images downloaded
# 4170 images downloaded
# 4180 images downloaded
# 4190 images downloaded
# 4200 images downloaded
# 4210 images downloaded
# 4220 images downloaded
# 4230 images downloaded
# 4240 images downloaded
# 4250 images downloaded
# 4260 images downloaded
# 4270 images downloaded
# 4280 images downloaded
# 4290 images downloaded
# 4300 images downloaded
# 4310 images downloaded
# 4320 images downloaded
# 4330 images downloaded
# 4340 images downloaded
# 4350 images downloaded
# 4360 images downloaded
# 4370 images downloaded
# 4380 images downloaded
# 4390 images downloaded
# 4400 images downloaded
# 4410 images downloaded
# 4420 images downloaded
# 4430 images downloaded
# 4440 images downloaded
# 4450 images downloaded
# 4460 images downloaded
# 4470 images downloaded
# 4480 images downloaded
# 4490 images downloaded
# 4500 images downloaded
# 4510 images downloaded
# 4520 images downloaded
# 4530 images downloaded
# 4540 images downloaded
# 4550 images downloaded
# 4560 images downloaded
# 4570 images downloaded
# 4580 images downloaded
# 4590 images downloaded
# 4600 images downloaded
# 4610 images downloaded
# 4620 images downloaded
# 4630 images downloaded
# 4640 images downloaded
# 4650 images downloaded
# 4660 images downloaded
# 4670 images downloaded
# 4680 images downloaded
# 4690 images downloaded
# 4700 images downloaded
# 4710 images downloaded
# 4720 images downloaded
# 4730 images downloaded
# 4740 images downloaded
# 4750 images downloaded
# 4760 images downloaded
# 4770 images downloaded
# 4780 images downloaded
# 4790 images downloaded
# 4800 images downloaded
# 4810 images downloaded
# 4820 images downloaded
# 4830 images downloaded
# 4840 images downloaded
# 4850 images downloaded
# 4860 images downloaded
# 4870 images downloaded
# 4880 images downloaded
# 4890 images downloaded
# 4900 images downloaded
# 4910 images downloaded
# 4920 images downloaded
# 4930 images downloaded
# 4940 images downloaded
# 4950 images downloaded
# 4960 images downloaded
# 4970 images downloaded
# 4980 images downloaded
# 4990 images downloaded
# 5000 images downloaded
# 5010 images downloaded
# 5020 images downloaded
# 5030 images downloaded
# 5040 images downloaded
# 5050 images downloaded
# 5060 images downloaded
# 5070 images downloaded
# 5080 images downloaded
# 5090 images downloaded
# 5100 images downloaded
# 5110 images downloaded
# 5120 images downloaded
# 5130 images downloaded
# 5140 images downloaded
# 5150 images downloaded
# 5160 images downloaded
# 5170 images downloaded
# 5180 images downloaded
# 5190 images downloaded
# 5200 images downloaded
# 5210 images downloaded
# 5220 images downloaded
# 5230 images downloaded
# 5240 images downloaded
# 5250 images downloaded
# 5260 images downloaded
# 5270 images downloaded
# 5280 images downloaded
# 5290 images downloaded
# 5300 images downloaded
# 5310 images downloaded
# 5320 images downloaded
# 5330 images downloaded
# 5340 images downloaded
# 5350 images downloaded
# 5360 images downloaded
# 5370 images downloaded
# 5380 images downloaded
# 5390 images downloaded
# 5400 images downloaded
# 5410 images downloaded
# 5420 images downloaded
# 5430 images downloaded
# 5440 images downloaded
# 5450 images downloaded
# 5460 images downloaded
# 5470 images downloaded
# 5480 images downloaded
# 5490 images downloaded
# 5500 images downloaded
# 5510 images downloaded
# 5520 images downloaded
# 5530 images downloaded
# 5540 images downloaded
# 5550 images downloaded
# 5560 images downloaded
# 5570 images downloaded
# 5580 images downloaded
# 5590 images downloaded
# 5600 images downloaded
# 5610 images downloaded
# 5620 images downloaded
# 5630 images downloaded
# 5640 images downloaded
# 5650 images downloaded
# 5660 images downloaded
# 5670 images downloaded
# 5680 images downloaded
# 5690 images downloaded
# 5700 images downloaded
# 5710 images downloaded
# 5720 images downloaded
# 5730 images downloaded
# 5740 images downloaded
# 5750 images downloaded
# 5760 images downloaded
# 5770 images downloaded
# 5780 images downloaded
# 5790 images downloaded
# 5800 images downloaded
# 5810 images downloaded
# 5820 images downloaded
# 5830 images downloaded
# 5840 images downloaded
# 5850 images downloaded
# 5860 images downloaded
# 5870 images downloaded
# 5880 images downloaded
# 5890 images downloaded
# 5900 images downloaded
# 5910 images downloaded
# 5920 images downloaded
# 5930 images downloaded
# 5940 images downloaded
# 5950 images downloaded
# 5960 images downloaded
# 5970 images downloaded
# 5980 images downloaded
# 5990 images downloaded
# 6000 images downloaded
# 6010 images downloaded
# 6020 images downloaded
# 6030 images downloaded
# 6040 images downloaded
# 6050 images downloaded
# 6060 images downloaded
# 6070 images downloaded
# 6080 images downloaded
# 6090 images downloaded
# 6100 images downloaded
# 6110 images downloaded
# 6120 images downloaded
# 6130 images downloaded
# 6140 images downloaded
# 6150 images downloaded
# 6160 images downloaded
# 6170 images downloaded
# 6180 images downloaded
# 6190 images downloaded
# 6200 images downloaded
# 6210 images downloaded
# 6220 images downloaded
# 6230 images downloaded
# 6240 images downloaded
# 6250 images downloaded
# 6260 images downloaded
# 6270 images downloaded
# 6280 images downloaded
# 6290 images downloaded
# 6300 images downloaded
# 6310 images downloaded
# 6320 images downloaded
# 6330 images downloaded
# 6340 images downloaded
# 6350 images downloaded
# 6360 images downloaded
# 6370 images downloaded
# 6380 images downloaded
# 6390 images downloaded
# 6400 images downloaded
# 6410 images downloaded
# 6420 images downloaded
# 6430 images downloaded
# 6440 images downloaded
# 6450 images downloaded
# 6460 images downloaded
# 6470 images downloaded
# 6480 images downloaded
# 6490 images downloaded
# 6500 images downloaded
# 6510 images downloaded
# 6520 images downloaded
# 6530 images downloaded
# 6540 images downloaded
# 6550 images downloaded
# 6560 images downloaded
# 6570 images downloaded
# 6580 images downloaded
# 6590 images downloaded
# 6600 images downloaded
# 6610 images downloaded
# 6620 images downloaded
# 6630 images downloaded
# 6640 images downloaded
# 6650 images downloaded
# 6660 images downloaded
# 6670 images downloaded
# 6680 images downloaded
# 6690 images downloaded
# 6700 images downloaded
# 6710 images downloaded
# 6720 images downloaded
# 6730 images downloaded
# 6740 images downloaded
# 6750 images downloaded
# 6760 images downloaded
# 6770 images downloaded
# 6780 images downloaded
# 6790 images downloaded
# 6800 images downloaded
# 6810 images downloaded
# 6820 images downloaded
# 6830 images downloaded
# 6840 images downloaded
# 6850 images downloaded
# 6860 images downloaded
# 6870 images downloaded
# 6880 images downloaded
# 6890 images downloaded
# 6900 images downloaded
# 6910 images downloaded
# 6920 images downloaded
# 6930 images downloaded
# 6940 images downloaded
# 6950 images downloaded
# 6960 images downloaded
# 6970 images downloaded
# 6980 images downloaded
# 6990 images downloaded
# 7000 images downloaded
# 7010 images downloaded
# 7020 images downloaded
# 7030 images downloaded
# 7040 images downloaded
# 7050 images downloaded
# 7060 images downloaded
# 7070 images downloaded
# 7080 images downloaded
# 7090 images downloaded
# 7100 images downloaded
# 7110 images downloaded
# 7120 images downloaded
# 7130 images downloaded
# 7140 images downloaded
# 7150 images downloaded
# 7160 images downloaded
# 7170 images downloaded
# 7180 images downloaded
# 7190 images downloaded
# 7200 images downloaded
# 7210 images downloaded
# 7220 images downloaded
# 7230 images downloaded
# 7240 images downloaded
# 7250 images downloaded
# 7260 images downloaded
# 7270 images downloaded
# 7280 images downloaded
# 7290 images downloaded
# 7300 images downloaded
# 7310 images downloaded
# 7320 images downloaded
# 7330 images downloaded
# 7340 images downloaded
# 7350 images downloaded
# 7360 images downloaded
# 7370 images downloaded
# 7380 images downloaded
# 7390 images downloaded
# 7400 images downloaded
# 7410 images downloaded
# 7420 images downloaded
# 7430 images downloaded
# 7440 images downloaded
# 7450 images downloaded
# 7460 images downloaded
# 7470 images downloaded
# 7480 images downloaded
# 7490 images downloaded
# 7500 images downloaded
# 7510 images downloaded
# 7520 images downloaded
# 7530 images downloaded
# 7540 images downloaded
# 7550 images downloaded
# 7560 images downloaded
# 7570 images downloaded
# 7580 images downloaded
# 7590 images downloaded
# 7600 images downloaded
# 7610 images downloaded
# 7620 images downloaded
# 7630 images downloaded
# 7640 images downloaded
# 7650 images downloaded
# 7660 images downloaded
# 7670 images downloaded
# 7680 images downloaded
# 7690 images downloaded
# 7700 images downloaded
# 7710 images downloaded
# 7720 images downloaded
# 7730 images downloaded
# 7740 images downloaded
# 7750 images downloaded
# 7760 images downloaded
# 7770 images downloaded
# 7780 images downloaded
# 7790 images downloaded
# 7800 images downloaded
# 7810 images downloaded
# 7820 images downloaded
# 7830 images downloaded
# 7840 images downloaded
# 7850 images downloaded
# 7860 images downloaded
# 7870 images downloaded
# 7880 images downloaded
# 7890 images downloaded
# 7900 images downloaded
# 7910 images downloaded
# 7920 images downloaded
# 7930 images downloaded
# 7940 images downloaded
# 7950 images downloaded
# 7960 images downloaded
# 7970 images downloaded
# 7980 images downloaded
# 7990 images downloaded
# 8000 images downloaded
# 8010 images downloaded
# 8020 images downloaded
# 8030 images downloaded
# 8040 images downloaded
# 8050 images downloaded
# 8060 images downloaded
# 8070 images downloaded
# 8080 images downloaded
# 8090 images downloaded
# 8100 images downloaded
# 8110 images downloaded
# 8120 images downloaded
# 8130 images downloaded
# 8140 images downloaded
# 8150 images downloaded
# 8160 images downloaded
# 8170 images downloaded
# 8180 images downloaded
# 8190 images downloaded
# 8200 images downloaded
# 8210 images downloaded
# 8220 images downloaded
# 8230 images downloaded
# 8240 images downloaded
# 8250 images downloaded
# 8260 images downloaded
# 8270 images downloaded
# 8280 images downloaded
# 8290 images downloaded
# 8300 images downloaded
# 8310 images downloaded
# 8320 images downloaded
# 8330 images downloaded
# 8340 images downloaded
# 8350 images downloaded
# 8360 images downloaded
# 8370 images downloaded
# 8380 images downloaded
# 8390 images downloaded
# 8400 images downloaded
# 8410 images downloaded
# 8420 images downloaded
# 8430 images downloaded
# 8440 images downloaded
# 8450 images downloaded
# 8460 images downloaded
# 8470 images downloaded
# 8480 images downloaded
# 8490 images downloaded
# 8500 images downloaded
# 8510 images downloaded
# 8520 images downloaded
# 8530 images downloaded
# 8540 images downloaded
# 8550 images downloaded
# 8560 images downloaded
# 8570 images downloaded
# 8580 images downloaded
# 8590 images downloaded
# 8600 images downloaded
# 8610 images downloaded
# 8620 images downloaded
# 8630 images downloaded
# 8640 images downloaded
# 8650 images downloaded
# 8660 images downloaded
# 8670 images downloaded
# 8680 images downloaded
# 8690 images downloaded
# 8700 images downloaded
# 8710 images downloaded
# 8720 images downloaded
# 8730 images downloaded
# 8740 images downloaded
# 8750 images downloaded
# 8760 images downloaded
# 8770 images downloaded
# 8780 images downloaded
# 8790 images downloaded
# 8800 images downloaded
# 8810 images downloaded
# 8820 images downloaded
# 8830 images downloaded
# 8840 images downloaded
# 8850 images downloaded
# 8860 images downloaded
# 8870 images downloaded
# 8880 images downloaded
# 8890 images downloaded
# 8900 images downloaded
# 8910 images downloaded
# 8920 images downloaded
# 8930 images downloaded
# 8940 images downloaded
# 8950 images downloaded
# 8960 images downloaded
# 8970 images downloaded
# 8980 images downloaded
# 8990 images downloaded
# 9000 images downloaded
# 9010 images downloaded
# 9020 images downloaded
# 9030 images downloaded
# 9040 images downloaded
# 9050 images downloaded
# 9060 images downloaded
# 9070 images downloaded
# 9080 images downloaded
# 9090 images downloaded
# 9100 images downloaded
# 9110 images downloaded
# 9120 images downloaded
# 9130 images downloaded
# 9140 images downloaded
# 9150 images downloaded
# 9160 images downloaded
# 9170 images downloaded
# 9180 images downloaded
# 9190 images downloaded
# 9200 images downloaded
# 9210 images downloaded
# 9220 images downloaded
# 9230 images downloaded
# 9240 images downloaded
# 9250 images downloaded
# 9260 images downloaded
# 9270 images downloaded
# 9280 images downloaded
# 9290 images downloaded
# 9300 images downloaded
# 9310 images downloaded
# 9320 images downloaded
# 9330 images downloaded
# 9340 images downloaded
# 9350 images downloaded
# 9360 images downloaded
# 9370 images downloaded
# 9380 images downloaded
# 9390 images downloaded
# 9400 images downloaded
# 9410 images downloaded
# 9420 images downloaded
# 9430 images downloaded
# 9440 images downloaded
# 9450 images downloaded
# 9460 images downloaded
# 9470 images downloaded
# 9480 images downloaded
# 9490 images downloaded
# 9500 images downloaded
# 9510 images downloaded
# 9520 images downloaded
# 9530 images downloaded
# 9540 images downloaded
# 9550 images downloaded
# 9560 images downloaded
# 9570 images downloaded
# 9580 images downloaded
# 9590 images downloaded
# 9600 images downloaded
# 9610 images downloaded
# 9620 images downloaded
# 9630 images downloaded
# 9640 images downloaded
# 9650 images downloaded
# 9660 images downloaded
# 9670 images downloaded
# 9680 images downloaded
